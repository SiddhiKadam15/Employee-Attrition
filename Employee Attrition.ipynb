# %% [markdown]
# # Bharat Intern - Employee attrition and performance
#
# ## Siddhi Kadam

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
df.drop(['EmployeeCount','StandardHours','Over18','EmployeeNumber'], axis=1, inplace=True)

# %%
columns = list(df.columns)
categorical = [data for data in columns if df[data].dtype=='object']
categorical
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %%
sns.countplot(x='Gender', hue='Attrition', data=df, palette='prism_r')
plt.show()

# %%
sns.countplot(x='Department', hue='Attrition', data=df, palette='prism_r')
plt.show()

# %%
sns.countplot(x='MaritalStatus', hue='Attrition', data=df, palette='prism_r')
plt.show()

# %%
sns.countplot(x='BusinessTravel', hue='Attrition', data=df, palette='prism_r')
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.countplot(x='JobRole', hue='Attrition', data=df, palette='prism_r')
plt.xticks(rotation=40)
plt.show()

# %%
sns.countplot(x='EducationField', hue='Attrition', data=df, palette='prism_r')
plt.xticks(rotation=40)
plt.show()

# %%
sns.countplot(x='OverTime', hue='Attrition', data=df, palette='prism_r')
plt.show()

# %% [markdown]
# Observations-
#
# Gender: Male employees quit more than female employees.
#
# Business Travel: The employees who travel rarely are more likely to quit than other employees.
#
# Marital Status: Employees who are single tend to quit their jobs more than the married/divorced.
#
# Department: Research and Development employees don't quit their jobs as much as the other departments.
#
# Job Role: Sales Executives, Laboratory Technicians and Research Scientists are more likely to quit than other employees.
#
# Education Field: Employees from Life Sciences, Medical and Marketing educational background are more likely to stay than other employees of different educational background.
#
# Over Time: Employees who do over time are likely to quit.

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Age', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='DistanceFromHome', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
sns.countplot(x='EnvironmentSatisfaction', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
sns.countplot(x='JobInvolvement', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
sns.countplot(x='JobLevel', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
sns.countplot(x='JobSatisfaction', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='TotalWorkingYears', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
sns.countplot(x='StockOptionLevel', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
sns.countplot(x='PerformanceRating', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
sns.countplot(x='PercentSalaryHike', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
sns.countplot(x='NumCompaniesWorked', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
sns.countplot(x='RelationshipSatisfaction', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
sns.countplot(x='WorkLifeBalance', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='YearsAtCompany', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
sns.countplot(x='YearsInCurrentRole', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
sns.countplot(x='YearsSinceLastPromotion', hue='Attrition', data=df, palette='cool')
plt.show()

# %%
sns.countplot(x='YearsWithCurrManager', hue='Attrition', data=df, palette='cool')
plt.show()

# %% [markdown]
# Observations-
#
# Young employees aged below 22 yrs, quit their jobs more.
#
# Employees who travel more than 10 kms to reach office, are more likely to quit.
#
# Environment Satisfaction, Job Satisfaction, Relationship Satisfaction, Job Involvement, Performance Rating, Stock Option Level, Work Life Balance- these features don't really help us in understanding the employees' attrition.
#
# Employees with low Job Level, Monthly Income, Percent Salary Hike, Total Working Years, Years At Company are prone to quitting their jobs.
#
# Employees who have spent more than 2 years with their current manager, are more likely to stay.
#
# Employees who have received promotion recently within 2 years, will stay than employees who haven't received any promotion for a long time.
#
# Employees who have worked in less than 2 comapanies, are more likely to stay.

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,cmap='Blues')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["Attrition"] = le.fit_transform(df.Attrition)

# %%
X = df.drop('Attrition',1)
Y = df.Attrition

# %%
columns_to_encode=[]
for i in X.columns:
    if df[i].nunique() < 20:
        columns_to_encode.append(i)

columns_to_encode
# Out:
# ['BusinessTravel',
#  'Department',
#  'Education',
#  'EducationField',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'NumCompaniesWorked',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
X=pd.get_dummies(X, columns=columns_to_encode, drop_first=True)
X
# Out:
#       Age  DailyRate  DistanceFromHome  HourlyRate  MonthlyIncome  \
# 0      41       1102                 1          94           5993
# 1      49        279                 8          61           5130
# 2      37       1373                 2          92           2090
# 3      33       1392                 3          56           2909
# 4      27        591                 2          40           3468
# ...   ...        ...               ...         ...            ...
# 1465   36        884                23          41           2571
# 1466   39        613                 6          42           9991
# 1467   27        155                 4          87           6142
# 1468   49       1023                 2          63           5390
# 1469   34        628                 8          82           4404
#
#       MonthlyRate  TotalWorkingYears  YearsAtCompany  \
# 0           19479                  8               6
# 1           24907                 10              10
# ...

# %% [markdown]
# ## Random Forest

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,train_size=0.8,random_state=42,stratify=Y)

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

rf = RandomForestClassifier()
rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
rf_pred = rf.predict(X_test)
print(classification_report(Y_test, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       247
#            1       0.57      0.09      0.15        47
#
#     accuracy                           0.84       294
#    macro avg       0.71      0.54      0.53       294
# weighted avg       0.81      0.84      0.79       294

# %%
tuned_parameters = [{'max_depth': [10,50,100,200], 'n_estimators': [50,100,200,500], 'max_features': ['sqrt', 'auto']}] 
rf = RandomForestClassifier() 
rf_clf = GridSearchCV(rf, tuned_parameters, cv=5) 
rf_clf.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid=[{'max_depth': [10, 50, 100, 200],
#                           'max_features': ['sqrt', 'auto'],
#                           'n_estimators': [50, 100, 200, 500]}])

# %%
rf = RandomForestClassifier(**rf_clf.best_params_) 
rf.fit( X_train, Y_train )
# Out:
# RandomForestClassifier(max_depth=10, max_features='sqrt')

# %%
rf_Y_train_pred = rf.predict(X_train)
rf_Y_test_pred = rf.predict(X_test)

# %%
sns.heatmap(confusion_matrix(Y_train, rf_Y_train_pred), annot=True, fmt='d')
print(classification_report(Y_train, rf_Y_train_pred))
print('Accuracy for the train data:', accuracy_score(Y_train, rf_Y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       986
#            1       1.00      0.59      0.75       190
#
#     accuracy                           0.93      1176
#    macro avg       0.96      0.80      0.85      1176
# weighted avg       0.94      0.93      0.93      1176
#
# Accuracy for the train data: 0.9345238095238095

# %%
sns.heatmap(confusion_matrix(Y_test, rf_Y_test_pred), annot=True, fmt='d')
print(classification_report(Y_test, rf_Y_test_pred))
print('Accuracy for the test data:', accuracy_score(Y_test, rf_Y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       247
#            1       0.50      0.06      0.11        47
#
#     accuracy                           0.84       294
#    macro avg       0.67      0.53      0.51       294
# weighted avg       0.79      0.84      0.78       294
#
# Accuracy for the test data: 0.8401360544217688
